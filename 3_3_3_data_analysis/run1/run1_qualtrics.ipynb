# %% [markdown]
# # Setup

# %% [markdown]
# ## Version Test

# %% [markdown]
# Originally created with `R` version `4.1.0`
#
# ![Screen Shot 2021-10-12 at 21.27.47.png](attachment:fbc05668-ce1b-4253-b867-17d823989e5d.png)

# %%
# Check version of R
version
# Out:
#                _
# platform       aarch64-apple-darwin20
# arch           aarch64
# os             darwin20
# system         aarch64, darwin20
# status
# major          4
# minor          2.0
# year           2022
# month          04
# day            22
# svn rev        82229
# language       R
# version.string R version 4.2.0 (2022-04-22)
# nickname       Vigorous Calisthenics

# %% [markdown]
# ## Load Libraries

# %%
library(tidyverse)
library(data.table)
library(broom)
library(dtplyr)
library(lme4) #for lmer & glmer models
library(lmerTest)
library(ggbeeswarm)
library(cowplot)
library(leaflet) # for maps
library(psych)
library(corrplot)
library(sjPlot) #for plotting lmer and glmer mods
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step
#
#
#
# Attaching package: ‘psych’
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha
#
#
# corrplot 0.92 loaded
#
# Registered S3 method overwritten by 'parameters':
#   method                         from
#   format.parameters_distribution datawizard
#
# Install package "strengejacke" from GitHub (`devtools::install_github("strengejacke/strengejacke")`) to load all sj-packages at once!
#
#
# Attaching package: ‘sjPlot’
#
#
# The following objects are masked from ‘package:cowplot’:
#
#     plot_grid, save_plot

# %% [markdown]
# # Import Data

# %% [markdown]
# ## Run 1 Onboarding/Offboarding

# %% [markdown]
# Run 1 | Sept - Dec 2022

# %%
dataFileNumeric = '/Users/djw/Documents/pCloud_synced/Academics/Projects/2020_thesis/thesis_experiments/3_experiments/3_3_experience_sampling/3_3_1_raw_data/run_1/run1_qualtrics_onboardingOffboarding.csv'
run1_q <- as.data.table(read_csv(dataFileNumeric, show_col_types = FALSE))
run1_q = run1_q[Status=='0'] # select non-preview, non-metadata rows

# %% [markdown]
# ## Rename Domains

# %% [markdown]
# ### Description

# %% [markdown]
# When doing the second and third versions of SONA testing some domains were being incorrectly labeled by number.
#
# For example starting at 4:
# ```
# 'ib_domains_success_4'
# 'ib_domains_success_5'
# 'ib_domains_success_6'
# 'ib_domains_success_7'
# ```
# And then jumpping around from 27 -> 29 -> 37 -> 31, etc.
# ```
# 'ib_domains_success_23'
# 'ib_domains_success_24'
# 'ib_domains_success_36'
# 'ib_domains_success_25'
# 'ib_domains_success_26'
# 'ib_domains_success_27'
# 'ib_domains_success_29'
# 'ib_domains_success_37'
# 'ib_domains_success_31'
# 'ib_domains_success_32'
# 'ib_domains_success_33'
# 'ib_domains_success_34'
# 'ib_domains_success_35'
# ```
# Since we are using a pass through logic on Qualtrics the ORDER of all the domains should remain the same for each category.
#
# This means that we can strip away the trailing number and replace it with a more meaningful domain description and that this should sync up for all version of data (sona I-III and retest) and categories...
#
# **NOTE:** There are some renamed and new domain categories in the retest data. This is not that important...more for refining the measure going forward.

# %% [markdown]
# ### Rename Function

# %%
# number of domains
domain_num = run1_q %>% select(contains('ib_domain_goal')) %>% as_tibble() %>% ncol()

# %%
rename_domains = function(df, domain_num){
    # list of domain categories
    ib_domain_cats = c('ambition', 'effort', 'external',
                       'goal', 'import', 'internal',
                       'rank', 'satis', 'source', 'specific',
                       'success', 'time'
                      )

    domain_names = c("Diet",
                     "Exercise",
                     "MentalPersonal_Health",
                     "Medical_Health",
                     "Sleep",
                     "Alcohol_drug",
                     "Online",
                     "Phone",
                     "Video games",
                     "Reading_leisure",
                     "SocialMedia",
                     "Sports_playing",
                     "TV_Streaming",
                     "Family",
                     "Friends",
                     "Partner",
                     "Social_life",
                     "Hobby",
                     "Housework",
                     "Cooking",
                     "Work_School",
                     "Environment",
                     "Culture",
                     "Learning",
                     "Self-Improvement",
                     "Volunteering",
                     "Community involvement",
                     "Admin",
                     "Future_Planning",
                     "Finances",
                     "Time_Management",
                     "Punctuality",
                     "Personal_Values",
                     "Other"
                    )

    for (i in 1:length(ib_domain_cats)) {
        # make a list of the existing names for each cateogry
        old_names = df %>%
            select(starts_with('ib_domain')) %>%
            select(contains(ib_domain_cats[i], ignore.case = FALSE)) %>%
            as_tibble() %>%
            names()

        # make a list of names with category and domain
        new_names = rep('ib_domain_', domain_num)
        new_names = paste0(new_names,ib_domain_cats[i], '_', domain_names)

        # replace existing names with new names
        df = df %>%
            rename_at(vars(all_of(old_names)), ~ new_names) %>%
            as_tibble()
    }

    return(df)
}

# %% [markdown]
# ### Rename Domains for each DF

# %%
run1_q = rename_domains(run1_q, domain_num)

# %% [markdown]
# ### Add Survey Version

# %%
run1_onB = run1_q %>%
    filter(EndDate < '2022-12-12 00:00:00')

run1_offB = run1_q %>%
    filter(EndDate >= '2022-12-12 00:00:00')

# %%
run1_onB$version = 'onB'
run1_offB$version = 'offB'

# %% [markdown]
# ### Match run 1 subjects

# %%
run1_subs_full = read_csv('/Users/djw/Documents/pCloud_synced/Academics/Projects/2020_thesis/thesis_experiments/3_experiments/3_3_experience_sampling/3_3_1_raw_data/run_1/run1_subjects.csv', show_col_types = FALSE)
run1_subs = run1_subs_full$`Student Number`

# %%
run1_onB$studentNumber = as.numeric(run1_onB$consent_sonaID)
run1_offB$studentNumber = as.numeric(run1_offB$consent_sonaID)

# %%
run1_onB = run1_onB %>%
    subset(studentNumber %in% run1_subs) %>%
    subset(Finished == 1)

run1_offB = run1_offB %>%
    subset(studentNumber %in% run1_subs) %>%
    subset(Finished == 1)

# %% [markdown]
# ### Remove duplicates

# %%
# take the first instance when duplicates
run1_onB = run1_onB %>%
   arrange(EndDate) %>% # use desc(EndDate) to take last instance
   group_by(studentNumber) %>%
    slice(1)

# %%
run1_offB = run1_offB %>%
   arrange(EndDate) %>% # use desc(EndDate) to take last instance
   group_by(studentNumber) %>%
    slice(1)

# %%
print(dim(run1_onB))
print(dim(run1_offB))
# Out:
# [1]   67 1844
# [1]   47 1844

# %%
length(unique(run1_onB$studentNumber))
# Out:
# [1] 67

# %%
length(unique(run1_offB$studentNumber))
# Out:
# [1] 47

# %% [markdown]
# ### Join

# %%
q_df = rbindlist(list(run1_offB, run1_onB), fill = TRUE)

# %% [markdown]
# # Timing

# %%
options(repr.plot.width = 8, repr.plot.height = 6)

timing = as.numeric(q_df$`Duration (in seconds)`)/60
hist(timing[timing<200])
describe(timing[timing<200])
# Out:
#    vars n  mean     sd       median trimmed  mad      min      max
# X1 1    95 66.55561 40.77626 54.8   61.64784 32.09829 17.43333 194.5667
#    range    skew     kurtosis  se
# X1 177.1333 1.112906 0.5428518 4.183556
# Plot with title “Histogram of timing[timing < 200]”

# %%
sum(timing>200)
# Out:
# [1] 19

# %% [markdown]
# Note that there were 35 peoople who took over 3 hours 20 min...should they be removed??

# %% [markdown]
# # Demographics

# %% [markdown]
# Select all columns that contain demographic information.
#
# This is pulled from the two demographic blocks in the questionnaire:
# 1. `demographic-standard`
# 2. `demographic-vib`

# %% [markdown]
# ## Convert height

# %%
# Calculate height in CM
q_df$height = as.numeric(q_df$`height#1_1`) * 30.48 + as.numeric(q_df$`height#2_1`) * 2.54

# note that there are some NAs as I had not set up the validation correctly. Should be fixed now...

# %% [markdown]
# ## Add BMI

# %%
# add bmi
q_df$bmi = (as.numeric(q_df$weight)/2.2) / (q_df$height/100)^2

# %% [markdown]
# ## Rate accomplishments

# %% [markdown]
# Need to rate accomplishments...

# %%
# loading google sheet where coding of accomplishments (1-7) is done
library(googlesheets4)

accomps = read_sheet("https://docs.google.com/spreadsheets/d/1NvRw00M79UANZkY0hGJ6A_E8IWg-pviysdbLOONZkYM/edit?usp=sharing")
# Out:
# Error in `cli::cli_abort()`:
# ! Can't get Google credentials.
# ℹ Are you running googlesheets4 in a non-interactive session? Consider:
# • Call `gs4_deauth()` to prevent the attempt to get credentials.
# • Call `gs4_auth()` directly with all necessary specifics.
# ℹ See gargle's "Non-interactive auth" vignette for more details:
# ℹ <https://gargle.r-lib.org/articles/non-interactive-auth.html>
# Traceback:
#
# 1. read_sheet("https://docs.google.com/spreadsheets/d/1NvRw00M79UANZkY0hGJ6A_E8IWg-pviysdbLOONZkYM/edit?usp=sharing")
# 2. get_cells(ss = ss, sheet = sheet, range = range, col_names_in_sheet = isTRUE(col_spec$col_names),
#  .     skip = skip, n_max = n_max)
# 3. gs4_get(ssid)
# 4. gs4_get_impl_(as_sheets_id(ss))
# 5. request_generate("sheets.spreadsheets.get", params = list(spreadsheetId = ssid,
#  .     fields = fields))
# 6. gargle::request_build(path = req$path, method = req$method, params = req$params,
#  .     body = req$body, token = token, base_url = req$base_url)
# 7. gs4_token()
# 8. gs4_auth()
# 9. gs4_abort(c("Can't get Google credentials.", i = "Are you running {.pkg googlesheets4} in a non-interactive \\\n             session? Consider:",
#  .     `*` = "Call {.fun gs4_deauth} to prevent the attempt to get credentials.",
#  .     `*` = "Call {.fun gs4_auth} directly with all necessary specifics.",
#  .     i = "See gargle's \"Non-interactive auth\" vignette for more details:",
#  .     i = "{.url https://gargle.r-lib.org/articles/non-interactive-auth.html}"))
# 10. cli::cli_abort(message = message, ..., class = c(class, "googlesheets4_error"),
#   .     .envir = .envir)
# 11. rlang::abort(format_error(escaped_message, .envir = .envir),
#   .     cli_bullets = message, ...)
# 12. signal_abort(cnd, .file)

# %%
# need to finish rating accomplishments
q_df$accomp_score = NA

# %%
demographics = q_df[, list(subjectID, StartDate, LocationLatitude, LocationLongitude,
                         gender, age, education, ethnicity, father_education, mother_education,
                         marital_status, employment_status, children_1, income, parents_income,
                         net_worth, parents_net_worth, housing_status,
                                macarthur_sss, macarthur_sss_parent, 
                                job, accomp_personal, accomp_career, accomp_score,
                                weight, height, bmi,
                                sat_score, gre_score_verbal, gre_score_quant, gpa_highschool, gpa_undergrad
                               )] # have added some more to this, and need to add race

# %% [markdown]
# # Intention-Behavior

# %% [markdown]
# All measures that relate to the intention-behavior gap will be collected in a single `dataframe`.
#
# To start we will just initialize a `dataframe` with `subjectID`

# %%
idx = which(names(q_df)=='studentNumber')
ib_measures_df = as.data.frame(q_df)[idx]

# %%
head(ib_measures_df, 3)
# Out:
#   studentNumber
# 1 1004444942
# 2 1004637244
# 3 1005242088

# %% [markdown]
# ### Overall Gap | Pre/Post

# %% [markdown]
# Before beginning the measure we had subjects provide an initial estimate of their **Intention Behavior Gap**.
#
# We asked:
#
# >When you consider the intentions or goals that you have for yourself, to what degree do you feel like you are successful in actually accomplishing those goals?
#
# >Please consider both big and small intentions or goals.
#
# We asked them to respond on a scale of `0` to `100`, where `100` would indicate that they had *NO GAP*
#
# Therefore the gap is calculated by:
# $$IBGap{_{pre}} = 100 - Score$$

# %%
# calculate
overall_gap_pre = 100-as.numeric(q_df$overall_success_pre_1)
# add to measure df
ib_measures_df$overall_gap_pre = overall_gap_pre

# %% [markdown]
# At the end of the measure we then asked the same question, requesting that they provide a single overall **Intention Behavior Gap** score.
#
# We asked:
#
# > Overall, When you consider all of the intentions and goals that you have for yourself, to what
# degree do you feel like you are successful in actually accomplishing these goals and intentions?
#
# > Please consider both big and small intentions or goals.
#
# Again we asked them to respond on a scale of `0` to `100`, where `100` would indicate that they had *NO GAP*
#
# Therefore the gap is calculated by:
# $$IBGap{_{post}} = 100 - Score$$

# %%
# calculate
overall_gap_post = 100-as.numeric(q_df$overall_success_post_1)
# add to measure df
ib_measures_df$overall_gap_post = overall_gap_post

# %% [markdown]
# ### Global Gap

# %% [markdown]
# `THIS IS NOT USED IN THE CURRENT VERSION OF THE MEASURE`
#
# The global action measure was an attempt to have people consider all the different **goals** and **intentions** they might set out for themselves across different timeframes:
# - day
# - week
# - month
# - year
#
# We then asked them to estimate both their:
# 1. Beginning of day **belief** about what percentage of their intentions they would accomplish
# 2. End of day actual **achievement** of their goals and intentions
#
# For example, for `day` the questions were:
#
# **Achievement**
# ```
# Please estimate to what extent, on AVERAGE, you achieve your goals, intentions, tasks and responsibilities on a DAILY basis.
#
# For example, at the END OF THE DAY when you think about all of the things you hoped to do that day, what percentage do you usually accomplish?
# ```
#
# **Belief**
# ```
# A similar question but...
#
# Now we would like to know at the BEGINNING OF EACH DAY, what percentage of your DAILY goals, tasks and responsibilities do you BELIEVE you will accomplish?
#
# In other words, sometimes we set goals for ourselves without really believing we’ll get to them, but at least hoping we will. We want you to estimate what percentage of your goals you really, honestly believe you will accomplish each day.
# ```
#
# We asked the same two questions for each timeframe listed above.

# %%
# create df with all vars
global_vars = as.data.frame(q_df) %>% 
  select(subjectID,
         global_day_actual_1, global_day_belief_1,
         global_week_actual_1, global_week_belief_1,
         global_month_actual_1, global_month_belief_1,
         global_year_actual_1, global_year_belief_1,
         global_overall_1
        )

# get average achievement gap
global_achieve = global_vars %>%
  select(contains('actual')) %>%
  lapply(as.numeric) %>%
  data.frame() %>%
  rowMeans(na.rm = TRUE)

# flip to get the gap instead of the achievement
global_achieve_gap = 100-global_achieve
# add to measure df
ib_measures_df$global_achieve_gap = global_achieve_gap

# get average belief gap
global_belief = global_vars %>%
  select(contains('belief')) %>%
  lapply(as.numeric) %>%
  data.frame() %>%
  rowMeans(na.rm = TRUE)

# flip to get the gap instead of the achievement
global_belief_gap = 100-global_belief
# add to measure df
ib_measures_df$global_belief_gap = global_belief_gap

# calculate difference between achieve and belief
ib_measures_df$belief_achieve_gap = global_belief - global_achieve
# Out:
# Error in `select()`:
# ! Can't subset columns that don't exist.
# ✖ Column `subjectID` doesn't exist.
# Traceback:
#
# 1. as.data.frame(q_df) %>% select(subjectID, global_day_actual_1,
#  .     global_day_belief_1, global_week_actual_1, global_week_belief_1,
#  .     global_month_actual_1, global_month_belief_1, global_year_actual_1,
#  .     global_year_belief_1, global_overall_1)
# 2. select(., subjectID, global_day_actual_1, global_day_belief_1,
#  .     global_week_actual_1, global_week_belief_1, global_month_actual_1,
#  .     global_month_belief_1, global_year_actual_1, global_year_belief_1,
#  .     global_overall_1)
# 3. select.data.frame(., subjectID, global_day_actual_1, global_day_belief_1,
#  .     global_week_actual_1, global_week_belief_1, global_month_actual_1,
#  .     global_month_belief_1, global_year_actual_1, global_year_belief_1,
#  .     global_overall_1)
# 4. tidyselect_fix_call(tidyselect::eval_select(expr(c(...)), .data),
#  .     call = error_call)
# 5. withCallingHandlers(expr, error = function(cnd) {
#  .     cnd$call <- call
#  .     cnd$parent <- NULL
#  .     cnd_signal(cnd)
#  . })
# 6. tidyselect::eval_select(expr(c(...)), .data)
# 7. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#  .     exclude = exclude, strict = strict, name_spec = name_spec,
#  .     allow_rename = allow_rename, error_call = error_call, )
# 8. with_subscript_errors(vars_select_eval(vars, expr, strict = strict,
#  .     data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#  .     allow_rename = allow_rename, type = type, error_call = error_call),
#  .     type = type)
# 9. tryCatch(with_entraced_errors(expr), vctrs_error_subscript = function(cnd) {
#  .     cnd$subscript_action <- subscript_action(type)
#  .     cnd$subscript_elt <- "column"
#  .     cnd_signal(cnd)
#  . })
# 10. tryCatchList(expr, classes, parentenv, handlers)
# 11. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 12. value[[3L]](cond)
# 13. cnd_signal(cnd)
# 14. signal_abort(cnd)
# 15. signalCondition(cnd)
# 16. (function (cnd)
#   . {
#   .     cnd$call <- call
#   .     cnd$parent <- NULL
#   .     cnd_signal(cnd)
#   . })(structure(list(message = "", trace = structure(list(call = list(
#   .     IRkernel::main(), kernel$run(), handle_shell(), executor$execute(msg),
#   .     tryCatch(evaluate(request$content$code, envir = .GlobalEnv,
#   .         output_handler = oh, stop_on_error = 1L), interrupt = function(cond) {
#   .         log_debug("Interrupt during execution")
#   .         interrupted <<- TRUE
#   .     }, error = .self$handle_error), tryCatchList(expr, classes,
#   .         parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), doTryCatch(return(expr), name, parentenv,
#   .         handler), tryCatchList(expr, names[-nh], parentenv, handlers[-nh]),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     evaluate_call(expr, parsed$src[[i]], envir = envir, enclos = enclos,
#   .         debug = debug, last = i == length(out), use_try = stop_on_error !=
#   .             2L, keep_warning = keep_warning, keep_message = keep_message,
#   .         output_handler = output_handler, include_timing = include_timing),
#   .     timing_fn(handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler))), handle(ev <- withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler)), try(f, silent = TRUE), tryCatch(expr,
#   .         error = function(e) {
#   .             call <- conditionCall(e)
#   .             if (!is.null(call)) {
#   .                 if (identical(call[[1L]], quote(doTryCatch)))
#   .                   call <- sys.call(-4L)
#   .                 dcall <- deparse(call, nlines = 1L)
#   .                 prefix <- paste("Error in", dcall, ": ")
#   .                 LONG <- 75L
#   .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                   type = "w")
#   .                 if (is.na(w))
#   .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                     type = "b")
#   .                 if (w > LONG)
#   .                   prefix <- paste0(prefix, "\n  ")
#   .             }
#   .             else prefix <- "Error : "
#   .             msg <- paste0(prefix, conditionMessage(e), "\n")
#   .             .Internal(seterrmessage(msg[1L]))
#   .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                 cat(msg, file = outFile)
#   .                 .Internal(printDeferredWarnings())
#   .             }
#   .             invisible(structure(msg, class = "try-error", condition = e))
#   .         }), tryCatchList(expr, classes, parentenv, handlers),
#   .     tryCatchOne(expr, names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), withCallingHandlers(withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), warning = wHandler, error = eHandler,
#   .         message = mHandler), withVisible(eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers)), eval_with_user_handlers(expr,
#   .         envir, enclos, user_handlers), eval(expr, envir, enclos),
#   .     eval(expr, envir, enclos), as.data.frame(q_df) %>% select(subjectID,
#   .         global_day_actual_1, global_day_belief_1, global_week_actual_1,
#   .         global_week_belief_1, global_month_actual_1, global_month_belief_1,
#   .         global_year_actual_1, global_year_belief_1, global_overall_1),
#   .     select(., subjectID, global_day_actual_1, global_day_belief_1,
#   .         global_week_actual_1, global_week_belief_1, global_month_actual_1,
#   .         global_month_belief_1, global_year_actual_1, global_year_belief_1,
#   .         global_overall_1), select.data.frame(., subjectID, global_day_actual_1,
#   .         global_day_belief_1, global_week_actual_1, global_week_belief_1,
#   .         global_month_actual_1, global_month_belief_1, global_year_actual_1,
#   .         global_year_belief_1, global_overall_1), tidyselect_fix_call(tidyselect::eval_select(expr(c(...)),
#   .         .data), call = error_call), withCallingHandlers(expr,
#   .         error = function(cnd) {
#   .             cnd$call <- call
#   .             cnd$parent <- NULL
#   .             cnd_signal(cnd)
#   .         }), tidyselect::eval_select(expr(c(...)), .data), eval_select_impl(data,
#   .         names(data), as_quosure(expr, env), include = include,
#   .         exclude = exclude, strict = strict, name_spec = name_spec,
#   .         allow_rename = allow_rename, error_call = error_call,
#   .         ), with_subscript_errors(vars_select_eval(vars, expr,
#   .         strict = strict, data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#   .         allow_rename = allow_rename, type = type, error_call = error_call),
#   .         type = type), tryCatch(with_entraced_errors(expr), vctrs_error_subscript = function(cnd) {
#   .         cnd$subscript_action <- subscript_action(type)
#   .         cnd$subscript_elt <- "column"
#   .         cnd_signal(cnd)
#   .     }), tryCatchList(expr, classes, parentenv, handlers), tryCatchOne(expr,
#   .         names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .         name, parentenv, handler), with_entraced_errors(expr),
#   .     try_fetch(expr, simpleError = function(cnd) {
#   .         abort(conditionMessage(cnd), call = conditionCall(cnd))
#   .     }), withCallingHandlers(expr, simpleError = function(cnd) {
#   .         {
#   .             .__handler_frame__. <- TRUE
#   .             .__setup_frame__. <- frame
#   .         }
#   .         out <- handlers[[1L]](cnd)
#   .         if (!inherits(out, "rlang_zap"))
#   .             throw(out)
#   .     }), vars_select_eval(vars, expr, strict = strict, data = x,
#   .         name_spec = name_spec, uniquely_named = uniquely_named,
#   .         allow_rename = allow_rename, type = type, error_call = error_call),
#   .     walk_data_tree(expr, data_mask, context_mask, error_call),
#   .     eval_c(expr, data_mask, context_mask), reduce_sels(node,
#   .         data_mask, context_mask, init = init), walk_data_tree(new,
#   .         data_mask, context_mask), as_indices_sel_impl(out, vars = vars,
#   .         strict = strict, data = data, call = error_call), as_indices_impl(x,
#   .         vars, call = call, strict = strict), chr_as_locations(x,
#   .         vars, call = call), vctrs::vec_as_location(x, n = length(vars),
#   .         names = vars), `<fn>`(), stop_subscript_oob(i = i, subscript_type = subscript_type,
#   .         names = names, subscript_action = subscript_action, subscript_arg = subscript_arg,
#   .         call = call), stop_subscript(class = "vctrs_error_subscript_oob",
#   .         i = i, subscript_type = subscript_type, ..., call = call),
#   .     abort(class = c(class, "vctrs_error_subscript"), i = i, ...,
#   .         call = vctrs_error_call(call))), parent = c(0L, 1L, 2L,
#   . 3L, 4L, 5L, 6L, 7L, 6L, 9L, 10L, 4L, 12L, 13L, 13L, 15L, 16L,
#   . 17L, 18L, 19L, 13L, 13L, 13L, 23L, 24L, 0L, 0L, 0L, 28L, 29L,
#   . 28L, 31L, 32L, 33L, 34L, 35L, 36L, 33L, 38L, 39L, 32L, 41L, 42L,
#   . 43L, 44L, 45L, 46L, 47L, 48L, 49L, 50L, 51L, 52L), visible = c(TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   . TRUE, TRUE, TRUE, FALSE, FALSE, FALSE, FALSE, FALSE), namespace = c("IRkernel",
#   . NA, "IRkernel", NA, "base", "base", "base", "base", "base", "base",
#   . "base", "evaluate", "evaluate", "evaluate", "evaluate", "base",
#   . "base", "base", "base", "base", "base", "base", "evaluate", "base",
#   . "base", NA, "dplyr", "dplyr", "dplyr", "base", "tidyselect",
#   . "tidyselect", "tidyselect", "base", "base", "base", "base", "tidyselect",
#   . "rlang", "base", "tidyselect", "tidyselect", "tidyselect", "tidyselect",
#   . "tidyselect", "tidyselect", "tidyselect", "tidyselect", "vctrs",
#   . "vctrs", "vctrs", "vctrs", "rlang"), scope = c("::", NA, "local",
#   . NA, "::", "local", "local", "local", "local", "local", "local",
#   . "::", ":::", "local", "local", "::", "::", "local", "local",
#   . "local", "::", "::", ":::", "::", "::", NA, "::", ":::", ":::",
#   . "::", "::", ":::", ":::", "::", "local", "local", "local", ":::",
#   . "::", "::", ":::", ":::", ":::", ":::", ":::", ":::", ":::",
#   . ":::", "::", "local", ":::", ":::", "::")), row.names = c(NA,
#   . -53L), version = 2L, class = c("rlang_trace", "rlib_trace", "tbl",
#   . "data.frame")), parent = NULL, i = "subjectID", subscript_type = "character",
#   .     names = c("StartDate", "EndDate", "Status", "IPAddress",
#   .     "Progress", "Duration (in seconds)", "Finished", "RecordedDate",
#   .     "ResponseId", "RecipientLastName", "RecipientFirstName",
#   .     "RecipientEmail", "ExternalReference", "LocationLatitude",
#   .     "LocationLongitude", "DistributionChannel", "UserLanguage",
#   .     "consent_1", "consent_2", "consent_3", "consent_4", "consent_sonaID",
#   .     "consent_prescreen", "social_media_1", "social_media_2",
#   .     "social_media_3", "social_media_4", "age", "gender", "hispanic",
#   .     "ethnicity", "education", "father_education", "mother_education",
#   .     "marital_status", "children_1", "employment_status", "social_media_time",
#   .     "income", "parents_income", "net_worth", "parents_net_worth",
#   .     "housing_status", "criminality#1_1", "criminality#1_2", "criminality#1_3",
#   .     "criminality#1_4", "criminality#1_5", "criminality#1_6",
#   .     "criminality#1_7", "criminality#1_8", "macarthur_sss", "macarthur_sss_parent",
#   .     "job", "accomp_career", "accomp_personal", "weight", "weight_dec20",
#   .     "height#1_1", "height#2_1", "standardized_tests_1", "standardized_tests_2",
#   .     "standardized_tests_3", "sat_score", "gre_score_verbal",
#   .     "gre_score_quant", "lsat_score", "gpa_highschool", "gpa_undergrad",
#   .     "student_status", "semesters_complete", "gpa_current", "performance_compare_1",
#   .     "classes_number", "1_class_name", "1_grade_goal_1", "1_grade_goal_2",
#   .     "1_grade_goal_3", "1_grade_predict_1", "1_grade_predict_2",
#   .     "1_grade_predict_3", "2_class_name", "2_grade_goal_1", "2_grade_goal_2",
#   .     "2_grade_goal_3", "2_grade_predict_1", "2_grade_predict_2",
#   .     "2_grade_predict_3", "3_class_name", "3_grade_goal_1", "3_grade_goal_2",
#   .     "3_grade_goal_3", "3_grade_predict_1", "3_grade_predict_2",
#   .     "3_grade_predict_3", "4_class_name", "4_grade_goal_1", "4_grade_goal_2",
#   .     "4_grade_goal_3", "4_grade_predict_1", "4_grade_predict_2",
#   .     "4_grade_predict_3", "5_class_name", "5_grade_goal_1", "5_grade_goal_2",
#   .     "5_grade_goal_3", "5_grade_predict_1", "5_grade_predict_2",
#   .     "5_grade_predict_3", "overall_success_pre_1", "ib_domain_goal_Diet",
#   .     "ib_domain_goal_Exercise", "ib_domain_goal_MentalPersonal_Health",
#   .     "ib_domain_goal_Medical_Health", "ib_domain_goal_Sleep",
#   .     "ib_domain_goal_Alcohol_drug", "ib_domain_goal_Online", "ib_domain_goal_Phone",
#   .     "ib_domain_goal_Video games", "ib_domain_goal_Reading_leisure",
#   .     "ib_domain_goal_SocialMedia", "ib_domain_goal_Sports_playing",
#   .     "ib_domain_goal_TV_Streaming", "ib_domain_goal_Family", "ib_domain_goal_Friends",
#   .     "ib_domain_goal_Partner", "ib_domain_goal_Social_life", "ib_domain_goal_Hobby",
#   .     "ib_domain_goal_Housework", "ib_domain_goal_Cooking", "ib_domain_goal_Work_School",
#   .     "ib_domain_goal_Environment", "ib_domain_goal_Culture", "ib_domain_goal_Learning",
#   .     "ib_domain_goal_Self-Improvement", "ib_domain_goal_Volunteering",
#   .     "ib_domain_goal_Community involvement", "ib_domain_goal_Admin",
#   .     "ib_domain_goal_Future_Planning", "ib_domain_goal_Finances",
#   .     "ib_domain_goal_Time_Management", "ib_domain_goal_Punctuality",
#   .     "ib_domain_goal_Personal_Values", "ib_domain_goal_Other",
#   .     "ib_domain_time_Diet", "ib_domain_time_Exercise", "ib_domain_time_MentalPersonal_Health",
#   .     "ib_domain_time_Medical_Health", "ib_domain_time_Sleep",
#   .     "ib_domain_time_Alcohol_drug", "ib_domain_time_Online", "ib_domain_time_Phone",
#   .     "ib_domain_time_Video games", "ib_domain_time_Reading_leisure",
#   .     "ib_domain_time_SocialMedia", "ib_domain_time_Sports_playing",
#   .     "ib_domain_time_TV_Streaming", "ib_domain_time_Family", "ib_domain_time_Friends",
#   .     "ib_domain_time_Partner", "ib_domain_time_Social_life", "ib_domain_time_Hobby",
#   .     "ib_domain_time_Housework", "ib_domain_time_Cooking", "ib_domain_time_Work_School",
#   .     "ib_domain_time_Environment", "ib_domain_time_Culture", "ib_domain_time_Learning",
#   .     "ib_domain_time_Self-Improvement", "ib_domain_time_Volunteering",
#   .     "ib_domain_time_Community involvement", "ib_domain_time_Admin",
#   .     "ib_domain_time_Future_Planning", "ib_domain_time_Finances",
#   .     "ib_domain_time_Time_Management", "ib_domain_time_Punctuality",
#   .     "ib_domain_time_Personal_Values", "ib_domain_time_Other",
#   .     "ib_domain_effort_Diet", "ib_domain_effort_Exercise", "ib_domain_effort_MentalPersonal_Health",
#   .     "ib_domain_effort_Medical_Health", "ib_domain_effort_Sleep",
#   .     "ib_domain_effort_Alcohol_drug", "ib_domain_effort_Online",
#   .     "ib_domain_effort_Phone", "ib_domain_effort_Video games",
#   .     "ib_domain_effort_Reading_leisure", "ib_domain_effort_SocialMedia",
#   .     "ib_domain_effort_Sports_playing", "ib_domain_effort_TV_Streaming",
#   .     "ib_domain_effort_Family", "ib_domain_effort_Friends", "ib_domain_effort_Partner",
#   .     "ib_domain_effort_Social_life", "ib_domain_effort_Hobby",
#   .     "ib_domain_effort_Housework", "ib_domain_effort_Cooking",
#   .     "ib_domain_effort_Work_School", "ib_domain_effort_Environment",
#   .     "ib_domain_effort_Culture", "ib_domain_effort_Learning",
#   .     "ib_domain_effort_Self-Improvement", "ib_domain_effort_Volunteering",
#   .     "ib_domain_effort_Community involvement", "ib_domain_effort_Admin",
#   .     "ib_domain_effort_Future_Planning", "ib_domain_effort_Finances",
#   .     "ib_domain_effort_Time_Management", "ib_domain_effort_Punctuality",
#   .     "ib_domain_effort_Personal_Values", "ib_domain_effort_Other",
#   .     "ib_domain_import_Diet", "ib_domain_import_Exercise", "ib_domain_import_MentalPersonal_Health",
#   .     "ib_domain_import_Medical_Health", "ib_domain_import_Sleep",
#   .     "ib_domain_import_Alcohol_drug", "ib_domain_import_Online",
#   .     "ib_domain_import_Phone", "ib_domain_import_Video games",
#   .     "ib_domain_import_Reading_leisure", "ib_domain_import_SocialMedia",
#   .     "ib_domain_import_Sports_playing", "ib_domain_import_TV_Streaming",
#   .     "ib_domain_import_Family", "ib_domain_import_Friends", "ib_domain_import_Partner",
#   .     "ib_domain_import_Social_life", "ib_domain_import_Hobby",
#   .     "ib_domain_import_Housework", "ib_domain_import_Cooking",
#   .     "ib_domain_import_Work_School", "ib_domain_import_Environment",
#   .     "ib_domain_import_Culture", "ib_domain_import_Learning",
#   .     "ib_domain_import_Self-Improvement", "ib_domain_import_Volunteering",
#   .     "ib_domain_import_Community involvement", "ib_domain_import_Admin",
#   .     "ib_domain_import_Future_Planning", "ib_domain_import_Finances",
#   .     "ib_domain_import_Time_Management", "ib_domain_import_Punctuality",
#   .     "ib_domain_import_Personal_Values", "ib_domain_import_Other",
#   .     "ib_domain_success_Diet", "ib_domain_success_Exercise", "ib_domain_success_MentalPersonal_Health",
#   .     "ib_domain_success_Medical_Health", "ib_domain_success_Sleep",
#   .     "ib_domain_success_Alcohol_drug", "ib_domain_success_Online",
#   .     "ib_domain_success_Phone", "ib_domain_success_Video games",
#   .     "ib_domain_success_Reading_leisure", "ib_domain_success_SocialMedia",
#   .     "ib_domain_success_Sports_playing", "ib_domain_success_TV_Streaming",
#   .     "ib_domain_success_Family", "ib_domain_success_Friends",
#   .     "ib_domain_success_Partner", "ib_domain_success_Social_life",
#   .     "ib_domain_success_Hobby", "ib_domain_success_Housework",
#   .     "ib_domain_success_Cooking", "ib_domain_success_Work_School",
#   .     "ib_domain_success_Environment", "ib_domain_success_Culture",
#   .     "ib_domain_success_Learning", "ib_domain_success_Self-Improvement",
#   .     "ib_domain_success_Volunteering", "ib_domain_success_Community involvement",
#   .     "ib_domain_success_Admin", "ib_domain_success_Future_Planning",
#   .     "ib_domain_success_Finances", "ib_domain_success_Time_Management",
#   .     "ib_domain_success_Punctuality", "ib_domain_success_Personal_Values",
#   .     "ib_domain_success_Other", "ib_domain_satis_Diet", "ib_domain_satis_Exercise",
#   .     "ib_domain_satis_MentalPersonal_Health", "ib_domain_satis_Medical_Health",
#   .     "ib_domain_satis_Sleep", "ib_domain_satis_Alcohol_drug",
#   .     "ib_domain_satis_Online", "ib_domain_satis_Phone", "ib_domain_satis_Video games",
#   .     "ib_domain_satis_Reading_leisure", "ib_domain_satis_SocialMedia",
#   .     "ib_domain_satis_Sports_playing", "ib_domain_satis_TV_Streaming",
#   .     "ib_domain_satis_Family", "ib_domain_satis_Friends", "ib_domain_satis_Partner",
#   .     "ib_domain_satis_Social_life", "ib_domain_satis_Hobby", "ib_domain_satis_Housework",
#   .     "ib_domain_satis_Cooking", "ib_domain_satis_Work_School",
#   .     "ib_domain_satis_Environment", "ib_domain_satis_Culture",
#   .     "ib_domain_satis_Learning", "ib_domain_satis_Self-Improvement",
#   .     "ib_domain_satis_Volunteering", "ib_domain_satis_Community involvement",
#   .     "ib_domain_satis_Admin", "ib_domain_satis_Future_Planning",
#   .     "ib_domain_satis_Finances", "ib_domain_satis_Time_Management",
#   .     "ib_domain_satis_Punctuality", "ib_domain_satis_Personal_Values",
#   .     "ib_domain_satis_Other", "ib_domain_specific_Diet", "ib_domain_specific_Exercise",
#   .     "ib_domain_specific_MentalPersonal_Health", "ib_domain_specific_Medical_Health",
#   .     "ib_domain_specific_Sleep", "ib_domain_specific_Alcohol_drug",
#   .     "ib_domain_specific_Online", "ib_domain_specific_Phone",
#   .     "ib_domain_specific_Video games", "ib_domain_specific_Reading_leisure",
#   .     "ib_domain_specific_SocialMedia", "ib_domain_specific_Sports_playing",
#   .     "ib_domain_specific_TV_Streaming", "ib_domain_specific_Family",
#   .     "ib_domain_specific_Friends", "ib_domain_specific_Partner",
#   .     "ib_domain_specific_Social_life", "ib_domain_specific_Hobby",
#   .     "ib_domain_specific_Housework", "ib_domain_specific_Cooking",
#   .     "ib_domain_specific_Work_School", "ib_domain_specific_Environment",
#   .     "ib_domain_specific_Culture", "ib_domain_specific_Learning",
#   .     "ib_domain_specific_Self-Improvement", "ib_domain_specific_Volunteering",
#   .     "ib_domain_specific_Community involvement", "ib_domain_specific_Admin",
#   .     "ib_domain_specific_Future_Planning", "ib_domain_specific_Finances",
#   .     "ib_domain_specific_Time_Management", "ib_domain_specific_Punctuality",
#   .     "ib_domain_specific_Personal_Values", "ib_domain_specific_Other",
#   .     "ib_domain_ambition_Diet", "ib_domain_ambition_Exercise",
#   .     "ib_domain_ambition_MentalPersonal_Health", "ib_domain_ambition_Medical_Health",
#   .     "ib_domain_ambition_Sleep", "ib_domain_ambition_Alcohol_drug",
#   .     "ib_domain_ambition_Online", "ib_domain_ambition_Phone",
#   .     "ib_domain_ambition_Video games", "ib_domain_ambition_Reading_leisure",
#   .     "ib_domain_ambition_SocialMedia", "ib_domain_ambition_Sports_playing",
#   .     "ib_domain_ambition_TV_Streaming", "ib_domain_ambition_Family",
#   .     "ib_domain_ambition_Friends", "ib_domain_ambition_Partner",
#   .     "ib_domain_ambition_Social_life", "ib_domain_ambition_Hobby",
#   .     "ib_domain_ambition_Housework", "ib_domain_ambition_Cooking",
#   .     "ib_domain_ambition_Work_School", "ib_domain_ambition_Environment",
#   .     "ib_domain_ambition_Culture", "ib_domain_ambition_Learning",
#   .     "ib_domain_ambition_Self-Improvement", "ib_domain_ambition_Volunteering",
#   .     "ib_domain_ambition_Community involvement", "ib_domain_ambition_Admin",
#   .     "ib_domain_ambition_Future_Planning", "ib_domain_ambition_Finances",
#   .     "ib_domain_ambition_Time_Management", "ib_domain_ambition_Punctuality",
#   .     "ib_domain_ambition_Personal_Values", "ib_domain_ambition_Other",
#   .     "ib_domain_internal_Diet", "ib_domain_internal_Exercise",
#   .     "ib_domain_internal_MentalPersonal_Health", "ib_domain_internal_Medical_Health",
#   .     "ib_domain_internal_Sleep", "ib_domain_internal_Alcohol_drug",
#   .     "ib_domain_internal_Online", "ib_domain_internal_Phone",
#   .     "ib_domain_internal_Video games", "ib_domain_internal_Reading_leisure",
#   .     "ib_domain_internal_SocialMedia", "ib_domain_internal_Sports_playing",
#   .     "ib_domain_internal_TV_Streaming", "ib_domain_internal_Family",
#   .     "ib_domain_internal_Friends", "ib_domain_internal_Partner",
#   .     "ib_domain_internal_Social_life", "ib_domain_internal_Hobby",
#   .     "ib_domain_internal_Housework", "ib_domain_internal_Cooking",
#   .     "ib_domain_internal_Work_School", "ib_domain_internal_Environment",
#   .     "ib_domain_internal_Culture", "ib_domain_internal_Learning",
#   .     "ib_domain_internal_Self-Improvement", "ib_domain_internal_Volunteering",
#   .     "ib_domain_internal_Community involvement", "ib_domain_internal_Admin",
#   .     "ib_domain_internal_Future_Planning", "ib_domain_internal_Finances",
#   .     "ib_domain_internal_Time_Management", "ib_domain_internal_Punctuality",
#   .     "ib_domain_internal_Personal_Values", "ib_domain_internal_Other",
#   .     "ib_domain_external_Diet", "ib_domain_external_Exercise",
#   .     "ib_domain_external_MentalPersonal_Health", "ib_domain_external_Medical_Health",
#   .     "ib_domain_external_Sleep", "ib_domain_external_Alcohol_drug",
#   .     "ib_domain_external_Online", "ib_domain_external_Phone",
#   .     "ib_domain_external_Video games", "ib_domain_external_Reading_leisure",
#   .     "ib_domain_external_SocialMedia", "ib_domain_external_Sports_playing",
#   .     "ib_domain_external_TV_Streaming", "ib_domain_external_Family",
#   .     "ib_domain_external_Friends", "ib_domain_external_Partner",
#   .     "ib_domain_external_Social_life", "ib_domain_external_Hobby",
#   .     "ib_domain_external_Housework", "ib_domain_external_Cooking",
#   .     "ib_domain_external_Work_School", "ib_domain_external_Environment",
#   .     "ib_domain_external_Culture", "ib_domain_external_Learning",
#   .     "ib_domain_external_Self-Improvement", "ib_domain_external_Volunteering",
#   .     "ib_domain_external_Community involvement", "ib_domain_external_Admin",
#   .     "ib_domain_external_Future_Planning", "ib_domain_external_Finances",
#   .     "ib_domain_external_Time_Management", "ib_domain_external_Punctuality",
#   .     "ib_domain_external_Personal_Values", "ib_domain_external_Other",
#   .     "ib_domain_source_Diet", "ib_domain_source_Exercise", "ib_domain_source_MentalPersonal_Health",
#   .     "ib_domain_source_Medical_Health", "ib_domain_source_Sleep",
#   .     "ib_domain_source_Alcohol_drug", "ib_domain_source_Online",
#   .     "ib_domain_source_Phone", "ib_domain_source_Video games",
#   .     "ib_domain_source_Reading_leisure", "ib_domain_source_SocialMedia",
#   .     "ib_domain_source_Sports_playing", "ib_domain_source_TV_Streaming",
#   .     "ib_domain_source_Family", "ib_domain_source_Friends", "ib_domain_source_Partner",
#   .     "ib_domain_source_Social_life", "ib_domain_source_Hobby",
#   .     "ib_domain_source_Housework", "ib_domain_source_Cooking",
#   .     "ib_domain_source_Work_School", "ib_domain_source_Environment",
#   .     "ib_domain_source_Culture", "ib_domain_source_Learning",
#   .     "ib_domain_source_Self-Improvement", "ib_domain_source_Volunteering",
#   .     "ib_domain_source_Community involvement", "ib_domain_source_Admin",
#   .     "ib_domain_source_Future_Planning", "ib_domain_source_Finances",
#   .     "ib_domain_source_Time_Management", "ib_domain_source_Punctuality",
#   .     "ib_domain_source_Personal_Values", "ib_domain_source_Other",
#   .     "ib_domain_rank_Diet", "ib_domain_rank_Exercise", "ib_domain_rank_MentalPersonal_Health",
#   .     "ib_domain_rank_Medical_Health", "ib_domain_rank_Sleep",
#   .     "ib_domain_rank_Alcohol_drug", "ib_domain_rank_Online", "ib_domain_rank_Phone",
#   .     "ib_domain_rank_Video games", "ib_domain_rank_Reading_leisure",
#   .     "ib_domain_rank_SocialMedia", "ib_domain_rank_Sports_playing",
#   .     "ib_domain_rank_TV_Streaming", "ib_domain_rank_Family", "ib_domain_rank_Friends",
#   .     "ib_domain_rank_Partner", "ib_domain_rank_Social_life", "ib_domain_rank_Hobby",
#   .     "ib_domain_rank_Housework", "ib_domain_rank_Cooking", "ib_domain_rank_Work_School",
#   .     "ib_domain_rank_Environment", "ib_domain_rank_Culture", "ib_domain_rank_Learning",
#   .     "ib_domain_rank_Self-Improvement", "ib_domain_rank_Volunteering",
#   .     "ib_domain_rank_Community involvement", "ib_domain_rank_Admin",
#   .     "ib_domain_rank_Future_Planning", "ib_domain_rank_Finances",
#   .     "ib_domain_rank_Time_Management", "ib_domain_rank_Punctuality",
#   .     "ib_domain_rank_Personal_Values", "ib_domain_rank_Other",
#   .     "1_goal_interact_1", "1_goal_interact_2", "1_goal_interact_3",
#   .     "1_goal_interact_4", "1_goal_interact_5", "1_goal_interact_6",
#   .     "1_goal_interact_7", "1_goal_interact_8", "1_goal_interact_9",
#   .     "1_goal_interact_10", "1_goal_interact_11", "1_goal_interact_12",
#   .     "1_goal_interact_13", "1_goal_interact_14", "1_goal_interact_15",
#   .     "1_goal_interact_16", "1_goal_interact_17", "1_goal_interact_18",
#   .     "1_goal_interact_19", "1_goal_interact_20", "1_goal_interact_21",
#   .     "1_goal_interact_22", "1_goal_interact_23", "1_goal_interact_24",
#   .     "1_goal_interact_25", "1_goal_interact_26", "1_goal_interact_27",
#   .     "1_goal_interact_28", "1_goal_interact_29", "1_goal_interact_30",
#   .     "1_goal_interact_31", "1_goal_interact_32", "1_goal_interact_33",
#   .     "1_goal_interact_34", "2_goal_interact_1", "2_goal_interact_2",
#   .     "2_goal_interact_3", "2_goal_interact_4", "2_goal_interact_5",
#   .     "33_goal_interact_29", "33_goal_interact_30", "33_goal_interact_31",
#   .     "33_goal_interact_32", "33_goal_interact_33", "33_goal_interact_34",
#   .     "34_goal_interact_1", "34_goal_interact_2", "34_goal_interact_3",
#   .     "34_goal_interact_4", "34_goal_interact_5", "34_goal_interact_6",
#   .     "34_goal_interact_7", "34_goal_interact_8", "34_goal_interact_9",
#   .     "34_goal_interact_10", "34_goal_interact_11", "34_goal_interact_12",
#   .     "34_goal_interact_13", "34_goal_interact_14", "34_goal_interact_15",
#   .     "34_goal_interact_16", "34_goal_interact_17", "34_goal_interact_18",
#   .     "34_goal_interact_19", "34_goal_interact_20", "34_goal_interact_21",
#   .     "34_goal_interact_22", "34_goal_interact_23", "34_goal_interact_24",
#   .     "34_goal_interact_25", "34_goal_interact_26", "34_goal_interact_27",
#   .     "34_goal_interact_28", "34_goal_interact_29", "34_goal_interact_30",
#   .     "34_goal_interact_31", "34_goal_interact_32", "34_goal_interact_33",
#   .     "34_goal_interact_34", "plan_detailed_1", "plan_variation_1",
#   .     "plan_goalnum_1", "plan_goal_select_1", "plan_goal_focus_1",
#   .     "plan_contingencies_1", "goals_ambition_1", "goals_pragmatic_r_1",
#   .     "goals_variability_1", "goals_conflic_1", "overall_success_post_1",
#   .     "meta_potential_4", "meta_gap_feelings_1", "questions_accuracy_1",
#   .     "questions_suggestion", "timing_conscient_hex_First Click",
#   .     "timing_conscient_hex_Last Click", "timing_conscient_hex_Page Submit",
#   .     "timing_conscient_hex_Click Count", "con_hex_1", "con_hex_2",
#   .     "con_hex_3r", "con_hex_4r", "con_hex_5r", "con_hex_6r", "con_hex_7",
#   .     "conscient_hex_attention", "con_hex_8r", "con_hex_9", "con_hex_10r",
#   .     "timing_flourishing_First Click", "timing_flourishing_Last Click",
#   .     "timing_flourishing_Page Submit", "timing_flourishing_Click Count",
#   .     "flourishing_1", "flourishing_2", "flourishing_3", "flourishing_4",
#   .     "flourishing_5", "flourishing_6", "flourishing_7", "flourishing_8",
#   .     "timing_food_First Click", "timing_food_Last Click", "timing_food_Page Submit",
#   .     "timing_food_Click Count", "food_fruitveg_1", "food_fruitveg_2",
#   .     "food_fruitveg_3", "food_fruitveg_4", "food_fruitveg_5",
#   .     "food_fruitveg_6", "food_fruitveg_7", "food_fruitveg_8",
#   .     "food_fruitveg_9", "food_fruitveg_10", "food_fat_1", "food_fat_2",
#   .     "food_fat_3", "food_fat_4", "food_fat_5", "food_fat_6", "food_fat_7",
#   .     "food_fat_8", "food_fat_9", "food_fat_10", "food_fat_11",
#   .     "food_fat_12", "food_fat_13", "food_fat_14", "food_fat_15",
#   .     "food_fat_16", "food_fat_17", "timing_harmony_First Click",
#   .     "timing_harmony_Last Click", "timing_harmony_Page Submit",
#   .     "timing_harmony_Click Count", "harmony_1", "harmony_2", "harmony_3",
#   .     "harmony_4", "harmony_5", "timing_qol_First Click", "timing_qol_Last Click",
#   .     "timing_qol_Page Submit", "timing_qol_Click Count", "qol_1",
#   .     "qol_2", "qol_3", "qol_4", "qol_5", "qol_6", "qol_7", "qol_8",
#   .     "qol_9", "qol_10", "qol_11", "qol_12", "qol_13", "qol_14",
#   .     "qol_15", "qol_16", "timing_swl_scale_First Click", "timing_swl_scale_Last Click",
#   .     "timing_swl_scale_Page Submit", "timing_swl_scale_Click Count",
#   .     "swl_scale_1", "swl_scale_2", "swl_scale_3", "swl_scale_4",
#   .     "swl_scale_5", "timing_sub_happiness_First Click", "timing_sub_happiness_Last Click",
#   .     "timing_sub_happiness_Page Submit", "timing_sub_happiness_Click Count",
#   .     "happiness_1", "happiness_2", "happiness_3", "happiness_4r",
#   .     "timing_social_des_First Click", "timing_social_des_Last Click",
#   .     "timing_social_des_Page Submit", "timing_social_des_Click Count",
#   .     "social_des_1", "social_des_2", "social_des_3", "social_des_4",
#   .     "social_des_5r", "social_des_6", "social_des_7r", "social_des_8",
#   .     "social_des_9r", "social_des_10r", "social_des_11", "social_des_12",
#   .     "social_des_13r", "timing_debrief_First Click", "timing_debrief_Last Click",
#   .     "timing_debrief_Page Submit", "timing_debrief_Click Count",
#   .     "debrief_form_1", "debrief_form_2", "PROLIFIC_PID", "time_demo_standard",
#   .     "time_demo_vib", "time_action_global", "time_action_category",
#   .     "time_ib_domain", "time_action_style", "time_value_ideo",
#   .     "time_value_nomo", "time_value_overall", "time_meta", "time_survey_feedback",
#   .     "time_consent", "time_ambition_scale", "time_bscs", "time_future",
#   .     "time_swl_cantril", "time_sec_work_ethic", "time_grit_short",
#   .     "time_tipi", "time_debrief", "time_need_for_cognition", "time_boredom_prone",
#   .     "time_ccs", "time_ambition_scale_end", "id", "version", "studentNumber",
#   .     "height", "bmi"), subscript_action = "subset", subscript_arg = "x",
#   .     call = chr_as_locations(x, vars, call = call), subscript_elt = "column"), class = c("vctrs_error_subscript_oob",
#   . "vctrs_error_subscript", "rlang_error", "error", "condition")))
# 17. cnd_signal(cnd)
# 18. signal_abort(cnd)

# %% [markdown]
# **Note to self**:
#
# Not sure how to think of `belief_achieve_gap` as a metric?
#
# Perhaps should be correlated with **optimism** and or **ambition**?

# %% [markdown]
# ### Categorical Gap

# %% [markdown]
# `THIS IS NOT USED IN NEWER VERSION OF THE MEASURE`
#
# This version of the measure asked people to estimate the time they spent **on average per weekday** for a number of time use categories.
#
# Subjects filled out how many hours they **actually** spent on each of these categories and also how much time they **intended** to spend on each category.
#
# To calculate the gap we calculate as follows:
#
# $$Gap = \frac{\sum_{i=1}^{i=k} intendCategory_{i} - 24}{24}$$
#
# where `k` is the number of categories of activities, and `intendCategory` is the duration of the activity
#
# **Note to self:** Could be interesting to see what categories have the biggest/smallest gaps and in which direction...

# %%
# select columns related to action categorical measurement
cat_intend = as.data.frame(q_df) %>%
  select(contains('cat_intend')) %>%
  lapply(as.numeric) %>%
  data.frame() %>%
  rowSums(na.rm = TRUE)

cat_intend_gap = ((cat_intend - 24)/24) * 100

# add to measure df
ib_measures_df$cat_intend_gap = cat_intend_gap

# %% [markdown]
# ### Domains

# %% [markdown]
# The domain questions is similar to the `categorical gap` measure in that it asks about specific categories of activity but it differs in a few ways:
#
# 1. Many more (34) categories (i.e. greater specificity)
# 2. Opportunity to indicate that you do not have a goal in a category. e.g. perhaps you sleep a certain number of hours each night but you really do not have any sort of sleep goal. If you don't have a goal then we do not count it
# 3. Opportunity to indicate how important your goal is in each category. This can be used to "weight" the intention behavior gap if we like.
# 4. Indicate additional attributes of your goals in each category including:
#     - `specificity`
#     - `satisfaction`
#     - `goal setting style`
#     - `internal motivation`
#     - `external motivation`
#     - `gap cause`
#     - `gap rank`
#
# **Note to self:** Many other things to look at here, for example:
# - what is the average gap if grouped by how important the goal is?
# - what is the average gap if grouped by external motivation vs. internal motivation?
# - etc...

# %% [markdown]
# #### Rescale Domain Importance
#
# **NOTE** We are NOT doing this for now.
#
# The weighted domain gap did not perform better than the standard gap in terms of correlating with validation measures.
#
# This is something that needs to be revisited.

# %%
# # Importance scaling function
# fun_import = function(x) {
#     (((x - 1) * (1.5 - 0.5)) / (7 - 1)) + 0.5
# }

# %%
# # rescale all importance columns
# scaled_domains[,grepl('import', colnames(scaled_domains))] = apply(scaled_domains[,grepl('import', colnames(scaled_domains))], 2, fun_import)

# %% [markdown]
# ### Domains | Unweighted

# %%
ib_domain_ix = which(grepl('ib_domain', colnames(q_df)) 
                     & !grepl('domain_rank', colnames(q_df)) 
                     & !grepl('domain_goal', colnames(q_df))
                     & !grepl('domain_amount', colnames(q_df))
                    )

# %%
# make numeric
domains = as_tibble(q_df)[, ib_domain_ix] %>%
    lapply(as.numeric) %>%
    as_tibble()

# %%
# select columns related to action categorical measurement
domain_success = domains %>%
  select(contains('ib_domain_success')) %>%
  data.frame() %>%
  rowMeans(na.rm = TRUE)

# gap is opposite of success
# but not exactly opposite as we are converting to a scale that includes 0 to allow for NO gap...
domain_gap = 100 - domain_success 

# add to measure df
ib_measures_df$domain_gap = domain_gap
ib_measures_df$version = q_df$version

# %% [markdown]
# #### Create DF IB Gap for all domains

# %%
domains$studentNumber = q_df$studentNumber
domains$version = q_df$version

# %%
ib_gap_domains = domains %>%
  select(contains('ib_domain_success'), 'studentNumber', 'version')

# %%
# convert "success" to gap
studentNumber = ib_gap_domains$studentNumber
ib_gap_domains = cbind(100 - select(ib_gap_domains, -c(studentNumber, version)), studentNumber)

# %%
ib_gap_domains$version = q_df$version

# %%
# rename domains (since it is now gap, and not success)
 domain_names = c("Diet",
                     "Exercise",
                     "MentalPersonal_Health",
                     "Medical_Health",
                     "Sleep",
                     "Alcohol_drug",
                     "Online",
                     "Phone",
                     "Video games",
                     "Reading_leisure",
                     "SocialMedia",
                     "Sports_playing",
                     "TV_Streaming",
                     "Family",
                     "Friends",
                     "Partner",
                     "Social_life",
                     "Hobby",
                     "Housework",
                     "Cooking",
                     "Work_School",
                     "Environment",
                     "Culture",
                     "Learning",
                     "Self-Improvement",
                     "Volunteering",
                     "Community involvement",
                     "Admin",
                     "Future_Planning",
                     "Finances",
                     "Time_Management",
                     "Punctuality",
                     "Personal_Values",
                     "Other"
                    )

new_names = paste0('ib_domain_gap_', c(domain_names, 'studentNumber', 'version'))
ib_gap_domains = setNames(ib_gap_domains, new_names)

# %%
head(ib_gap_domains, 3)
# Out:
#   ib_domain_gap_Diet ib_domain_gap_Exercise ib_domain_gap_MentalPersonal_Health
# 1 NA                 29                     NA
# 2 31                 89                     63
# 3 NA                 NA                     NA
#   ib_domain_gap_Medical_Health ib_domain_gap_Sleep ib_domain_gap_Alcohol_drug
# 1 NA                           NA                  NA
# 2 NA                           18                  NA
# 3 NA                           NA                  NA
#   ib_domain_gap_Online ib_domain_gap_Phone ib_domain_gap_Video games
# 1 NA                   71                  NA
# 2 NA                   67                   5
# 3 NA                   NA                  NA
#   ib_domain_gap_Reading_leisure ⋯ ib_domain_gap_Community involvement
# 1 NA                            ⋯ NA
# 2 88                            ⋯ 70
# 3 NA                            ⋯ NA
#   ib_domain_gap_Admin ib_domain_gap_Future_Planning ib_domain_gap_Finances
# 1 NA                  NA                            NA
# 2 NA                  67                            46
# 3 NA                  34                            NA
#   ib_domain_gap_Time_Management ib_domain_gap_Punctuality
# 1 NA                            NA
# 2 63                            84
# 3 NA                            NA
#   ib_domain_gap_Personal_Values ib_domain_gap_Other ib_domain_gap_studentNumber
# 1 NA                            NA                  1004444942
# 2 76                            16                  1004637244
# 3 NA                            NA                  1005242088
#   ib_domain_gap_version
# 1 offB
# 2 offB
# 3 offB

# %%
head(ib_measures_df, 3)
# Out:
#   studentNumber overall_gap_pre overall_gap_post domain_gap version
# 1 1004444942    29              37               36.80000   offB
# 2 1004637244    30              23               52.47826   offB
# 3 1005242088    14              14               18.00000   offB

# %% [markdown]
# ### Domains | Weighted

# %% [markdown]
# Assuming that people don't care about all domains equally, we think that the gap should reflect this.
#
# In other words if you only care a bit about sleep and a lot about diet then a gap of 10% matters **more** in terms of diet.
#
# **Note to self**: There is probably some point of indifference where improving diet and improving sleep converge...
#
# ---
#
# The methods we are using is to use the following formula:
#
# $$Gap = \frac{\sum_{i=1}^{i=k} ibDomainGap_{i} * ibDomainImportance_{i}}{k}$$
#
# where `k` is the number of categories of domains, `ibDomainGap` is the goal domain, and `ibDomainImportance` is how important that domain is to the subject.
#
# Note that `ibDomainImportance` was originally on a 7 point Likert scale but has been re-scaled to a 0.5 - 1.5 scale so that the gap is downweighted for domains that are less important and upweighted for domains that are more important.

# %%
domain_success = scaled_domains %>%
    select(contains('ib_domains_success'))%>%
    data.frame()

# %%
head(describe(domain_success), 3)
# Out:
#                      vars n   mean     sd       median trimmed  mad      min
# ib_domains_success_1 1    204 3.777059 1.733503 4.00   3.783415 2.223900 0.94
# ib_domains_success_2 2    244 3.604426 1.877440 3.97   3.553776 2.312856 0.94
# ib_domains_success_3 3    221 3.817828 1.636049 3.94   3.807458 2.134944 0.94
#                      max range skew        kurtosis   se
# ib_domains_success_1 7   6.06  -0.12867921 -1.0431543 0.1213695
# ib_domains_success_2 7   6.06   0.10067246 -1.2424231 0.1201908
# ib_domains_success_3 7   6.06   0.08156233 -0.8515728 0.1100526

# %%
# convert success to gap...
# using 7 instead of 8 to flip values but include 0
gap = 7-domain_success

# %%
importance = scaled_domains %>%
    select(contains('ib_domains_import')) %>%
    data.frame()

# %%
head(gap,2)
# Out:
#   ib_domains_success_1 ib_domains_success_2 ib_domains_success_3
# 1 1.5                  1.5                  1.5
# 2  NA                  3.0                   NA
#   ib_domains_success_4 ib_domains_success_5 ib_domains_success_6
# 1 1.5                  1.5                   3
# 2  NA                   NA                  NA
#   ib_domains_success_7 ib_domains_success_8 ib_domains_success_9
# 1 NA                   NA                   NA
# 2 NA                   NA                   NA
#   ib_domains_success_10 ⋯ ib_domains_success_23 ib_domains_success_24
# 1 NA                    ⋯ 1.5                   NA
# 2 NA                    ⋯  NA                   NA
#   ib_domains_success_25 ib_domains_success_26 ib_domains_success_27
# 1  3                    1.5                    0
# 2 NA                     NA                   NA
#   ib_domains_success_28 ib_domains_success_29 ib_domains_success_30
# 1  0                     0                     0
# 2 NA                    NA                    NA
#   ib_domains_success_31 ib_domains_success_32
# 1  0                    0
# 2 NA                    0

# %%
head(importance, 2)
# Out:
#   ib_domains_import_1 ib_domains_import_2 ib_domains_import_3
# 1 1.25                1.00                 1
# 2   NA                1.25                NA
#   ib_domains_import_4 ib_domains_import_5 ib_domains_import_6
# 1 1.25                 1                  0.5
# 2   NA                NA                   NA
#   ib_domains_import_7 ib_domains_import_8 ib_domains_import_9
# 1 NA                  NA                  NA
# 2 NA                  NA                  NA
#   ib_domains_import_10 ⋯ ib_domains_import_23 ib_domains_import_24
# 1 NA                   ⋯ 1.5                  NA
# 2 NA                   ⋯  NA                  NA
#   ib_domains_import_25 ib_domains_import_26 ib_domains_import_27
# 1 1.25                 1.5                  1.25
# 2   NA                  NA                    NA
#   ib_domains_import_28 ib_domains_import_29 ib_domains_import_30
# 1 1.5                  1.25                 1.25
# 2  NA                    NA                   NA
#   ib_domains_import_31 ib_domains_import_32
# 1 1.5                  1.5
# 2  NA                  1.5

# %%
w_domain_gap = gap * importance
head(w_domain_gap, 3)
# Out:
#   ib_domains_success_1 ib_domains_success_2 ib_domains_success_3
# 1 1.875                1.50                 1.50
# 2    NA                3.75                   NA
# 3 2.250                4.50                 2.25
#   ib_domains_success_4 ib_domains_success_5 ib_domains_success_6
# 1 1.875                1.50                 1.5
# 2    NA                  NA                  NA
# 3    NA                2.25                 0.0
#   ib_domains_success_7 ib_domains_success_8 ib_domains_success_9
# 1 NA                    NA                   NA
# 2 NA                    NA                   NA
# 3 NA                   4.5                  4.5
#   ib_domains_success_10 ⋯ ib_domains_success_23 ib_domains_success_24
# 1    NA                 ⋯ 2.25                    NA
# 2    NA                 ⋯   NA                    NA
# 3 5.625                 ⋯   NA                  3.75
#   ib_domains_success_25 ib_domains_success_26 ib_domains_success_27
# 1 3.75                  2.25                  0.000
# 2   NA                    NA                     NA
# 3 3.75                  3.75                  1.875
#   ib_domains_success_28 ib_domains_success_29 ib_domains_success_30
# 1  0                    0.00                  0.0
# 2 NA                      NA                   NA
# 3 NA                    2.25                  4.5
#   ib_domains_success_31 ib_domains_success_32
# 1  0                    0.000
# 2 NA                    0.000
# 3  0                    1.875

# %%
# avg across rows
w_domain_gap = w_domain_gap %>%
    rowMeans(na.rm = TRUE)

# add to measure df
ib_measures_df$w_domain_gap = w_domain_gap

# %% [markdown]
# ### Eisenhower Matrix

# %% [markdown]
# We asked subjects to estimate the amount of time they spend in each of the four quadrants defiend by the [Eisenhower Matrix](https://jamesclear.com/eisenhower-box).
#
# <img src="attachment:432b02f8-95a4-4761-a9b5-c5fce5450f99.png" alt="Drawing" style="width: 400px;"/>
#
# > "What is important is seldom urgent and what is urgent is seldom important."
# >
# > -*Dwight Eisenhower, 34th President of the United States*

# %%
eisen_quad = as.data.frame(qn_df) %>%
  select(subjectID, contains('eisen')) %>%
  lapply(as.numeric) %>%
  data.frame() %>%
    rename(eisen_urg_imp = plan_eisenhow_1,
           eisen_Xurg_imp = plan_eisenhow_2,
           eisen_urg_Ximp = plan_eisenhow_3,
           eisen_Xurg_Ximp = plan_eisenhow_4
          )

# %% [markdown]
# # Validation Measures

# %% [markdown]
# Measure were selected for validation that we thought should correlate with the intention behavior gap measure.

# %% [markdown]
# **Note to self:** Need to deal with the cell below

# %%
# # test for people choosing only one score
# test_range = socialQs
# which(apply(test_range[,-1], 1, range)[2,] - apply(test_range[,-1], 1, range)[1,] ==0)

# # perform reliability analysis
# factor_data %>% select(paste0('Item', 13:17)) %>% alpha(keys = TRUE)

# %% [markdown]
# ### Conscientiousness HEX

# %% [markdown]
# [Link](https://docs.google.com/document/d/1b0WjZsNsMxHur6lm0tFo11LWIF7kCtC6WtYa6S6lGAc/edit)
#
# - 1: strongly disagree
# - 5: strongly agree

# %%
conscientiousness_hex <- select(q_df, studentNumber, version, starts_with("con_hex")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()

conscientiousness_hex = as_tibble(conscientiousness_hex)
# select reversed score columns
cols = conscientiousness_hex %>% select(contains('r_')) %>% names()
# reverse their scores
conscientiousness_hex[, cols] = 6 - conscientiousness_hex[, cols]
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %%
conscientiousness_hex_s = conscientiousness_hex %>%
  mutate(con_hex_score = rowMeans(.[,c(2:dim(conscientiousness_hex)[2])], na.rm = T)) %>%
  select(con_hex_score)

# %% [markdown]
# ### Flourishing

# %% [markdown]
# [Link](https://docs.google.com/document/d/14yEdkOxY-wrde67vkZFGWRpXYQnvbM3VbkS-M4O61Io/edit)
#
# **7 Point Likert**
# 1. Strongly disagree
# 7. Strongly agree
#
# No reverse scoring

# %%
flourishing <- select(q_df, studentNumber, version, starts_with("flourishing")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %%
flourishing_s = flourishing %>%
  as_tibble() %>%
  mutate(flourish_score = rowMeans(.[,c(2:dim(flourishing)[2])], na.rm = T)) %>%
  select(flourish_score)

# %% [markdown]
# ### Food Screener

# %% [markdown]
# [Link](https://docs.google.com/document/d/1kP5gELHH__i5chog26FsoMkZIh02cZrf8s1PFrIkesQ/edit#)
#
# **Fruit & Vegetable Screener**: Likert 0-5
# - 0 = less than 1/WEEK
# - 1 = Once a WEEK
# - 2 = 2-3 times a WEEK
# - 3 = 4-6 times a WEEK
# - 4 = Once a DAY
# - 5 = 2+ a DAY
#
# **Fat Screener**: Likert 0-4
# - 0 = 1/MONTHor less
# - 1 = 2-3 times a MONTH
# - 2 = 1-2 times a WEEK
# - 3 = 3-4 times a WEEK
# - 4 = 5+ times a WEEK
#
# For scoring basically higher scores just mean you consume items in that category more frequently
#
# No reverse scoring

# %%
food_screener <- select(q_df, studentNumber, version, starts_with("food")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()

food_screener = as_tibble(food_screener)
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %%
# subscales
fat = food_screener %>% select(contains('fat')) %>% rowMeans(na.rm = T)
fruit_veg = food_screener %>% select(contains('fruit')) %>% rowMeans(na.rm = T)

# join
food_screener_s = tibble(fat, fruit_veg)

# %% [markdown]
# ### Harmony in Life

# %% [markdown]
# [Link](https://docs.google.com/document/d/1Fj-qJIvi43FleOg7lG7SXeIvGEtAYDy_MZUP8D2-fT0/edit#)
#
# Emphasizes psychological balance and flexibility in life.
#
# **7 Point Likert**
# - 7 - Strongly agree
# - 1 - Strongly disagree
#
# No reverse scoring

# %%
harmony <- select(q_df, studentNumber, version, starts_with("harmony")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %%
harmony_s = harmony %>%
  as_tibble() %>%
  mutate(harmony_score = rowMeans(.[,c(2:dim(harmony)[2])], na.rm = T)) %>%
  select( harmony_score)

# %% [markdown]
# ### Quality of Life

# %% [markdown]
# [Link](https://docs.google.com/document/d/1_j2ziDtn_QfTM7Ow07-BB72OgbZ4yjplGwO2Y9i6aYw/edit#)
#
# > The QOLS is a valid instrument for measuring quality of life across patient groups and cultures and is conceptually distinct from health status or other causal indicators of quality of life.
#
#
# **7 Point Likert**
# - 7 - Delighted
# - 6 - Pleased
# - 5 - Mostly Satisfied
# - 4 - Mixed
# - 3 - Mostly Dissatisfied
# - 2 - Unhappy
# - 1 - Terrible
#
# No reverse scoring

# %%
qualityLife <- select(q_df, studentNumber, version, starts_with("qol")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %%
qualityLife_s = qualityLife %>%
  as_tibble() %>%
  mutate(qualityLife_score = rowMeans(.[,c(2:dim(qualityLife)[2])], na.rm = T)) %>%
  select( qualityLife_score)

# %% [markdown]
# ### SWLS (5)

# %% [markdown]
# [Link](https://docs.google.com/document/d/1Rp-afpwpUtZTr6t_I5gcXyKvUpUix2GYbQ0viIJAbcM/edit)
#
# - 1: strongly disagre
# - 7: strongly agree
# - no reverse scoring

# %%
SWL5 <- select(q_df, studentNumber, version, starts_with("swl_scale")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()

SWL5_s = SWL5 %>%
  as_tibble() %>%
  mutate(SWL5_score = rowMeans(.[,c(2:dim(SWL5)[2])], na.rm = T)) %>%
  select( SWL5_score)
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %% [markdown]
# ### Social Desirability

# %% [markdown]
# [Link](https://docs.google.com/document/d/176SizGcg7u4SyskMlSAPxifTxk53i1GeEPeSbW4XE6s/edit#)
#
# > A high score indicates a social desirability response tendency
#
# **True/False**
# - T=1, F=2)
# - Reverse score the following items: 5, 7, 9, 10, 13

# %%
socialD <- select(q_df, studentNumber, version, starts_with("social")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %%
socialD = as_tibble(socialD)
# select reversed score columns
cols = socialD %>% select(ends_with('r')) %>% names()
# reverse their scores
socialD[, cols] = 3 - socialD[, cols]

# %%
socialD_s = socialD %>%
  mutate(socialD_score = rowMeans(.[,c(2:dim(socialD)[2])], na.rm = T)) %>%
  select(socialD_score)

# %% [markdown]
# ### Subjective Happiness

# %% [markdown]
# [Link](https://docs.google.com/document/d/1QHS7y2EYv66X6khnsYcfYEAklRmmf1N9lF8lpaYkLlQ/edit)
#
# > global subjective happiness.
#
# > Two items ask respondents to characterize themselves using both absolute ratings and ratings relative to peers, whereas the other two items offer brief descriptions of happy and unhappy individuals and ask respondents the extent to which each characterization describes them.
#
# - 1: Not at all
# - 7: A great deal
# - Reverse scoring: 4

# %%
subjectHappy <- select(q_df, studentNumber, version, starts_with("happiness")) %>% as_tibble() %>% mutate_all(as.numeric) %>% data.table()

subjectHappy = as_tibble(subjectHappy)
# select reversed score columns
cols = subjectHappy %>% select(ends_with('r')) %>% names()
# reverse their scores
subjectHappy[, cols] = 6 - subjectHappy[, cols]
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”

# %%
subjectHappy_s = subjectHappy %>%
  mutate(subjectHappy_score = rowMeans(.[,c(2:dim(subjectHappy)[2])], na.rm = T)) %>%
  select(subjectHappy_score)

# %% [markdown]
# # Join Scales

# %%
q_df$conscientiousness_hex = conscientiousness_hex_s
q_df$flourishing = flourishing_s
q_df$food_screener_fat = food_screener_s$fat
q_df$food_screener_fruit_veg = food_screener_s$fruit_veg
q_df$harmony = harmony_s
q_df$qualityLife = qualityLife_s
q_df$SWL5 = SWL5_s
q_df$socialD = socialD_s
q_df$subjectHappy = subjectHappy_s

# %% [markdown]
# ## Split to onboarding offboarding

# %%
onB = q_df %>%
    filter(version == 'onB') %>%
    select(-version) %>%
    as_tibble()

offB = q_df %>%
    filter(version == 'offB') %>%
        select(-version) %>%
    as_tibble()

# %%
colnames(onB) <- paste0('onB_', colnames(onB))
onB$studentNumber = onB$onB_studentNumber
onB = onB %>% select(-onB_studentNumber)

# %%
colnames(offB) <- paste0('offB_', colnames(offB))
offB$studentNumber = offB$offB_studentNumber
offB = offB %>% select(-offB_studentNumber)

# %%
q_onOff = merge(onB, offB, by = 'studentNumber', all=TRUE)

# %%
run1_subs_full = run1_subs_full %>%
    select(c(ParticipantIdentifier, `Student Number`)) %>%
rename(
        studentNumber = `Student Number`
    )

# %%
q_onOff = merge(x = q_onOff, y = run1_subs_full, by = "studentNumber", all.x = TRUE)

# %% [markdown]
# ### Remove sensitive/irrelevant columns

# %%
q_onOff = q_onOff %>%
    select(-c(offB_consent_sonaID, onB_consent_sonaID,
              offB_social_media_1, offB_social_media_2, offB_social_media_3, offB_social_media_4, 
              onB_social_media_1, onB_social_media_2, onB_social_media_3, onB_social_media_4, 
              studentNumber,
              offB_RecipientFirstName, offB_RecipientLastName, offB_RecipientEmail,
              onB_RecipientFirstName, onB_RecipientLastName, onB_RecipientEmail,
              offB_LocationLatitude, offB_LocationLongitude,
              onB_LocationLatitude, onB_LocationLongitude,
              onB_IPAddress, offB_IPAddress,
              
             ))

# %%
write_csv(q_onOff, '/Users/djw/Documents/pCloud_synced/Academics/Projects/2020_thesis/thesis_experiments/3_experiments/3_3_experience_sampling/3_3_2_processed_data/run1_qualtrics.csv')

# %%
filename = paste0('../../3_1_2_processed_data/VIB_measure_cleaned_data', Sys.Date(), '.RData')

# Save created dataframes for analysis
save(q_df, qn_df, ib_measures_df, validation_measures, demographics, ib_gap_domains,
     file = filename)

# %% [markdown]
# ## Streamlit file

# %%
# create larger file
write.csv(demographics, '../../3_1_2_processed_data/streamlit_demo.csv')

# %%
# create larger file
df_streamlit = merge(ib_measures_df, validation_measures, by = 'subjectID') %>%
  merge(eisen_quad, by= 'subjectID')

write.csv(df_streamlit, '../../3_1_2_processed_data/streamlit.csv')

# %%
head(df_streamlit)
# Out:
#   subjectID overall_gap_pre overall_gap_post global_achieve_gap
# 1 1         15              19               22.50
# 2 2         55              60               49.75
# 3 3         40              35               36.25
# 4 4         27              52                7.25
# 5 5         15              25               21.75
# 6 6         30              40               22.50
#   global_belief_gap belief_achieve_gap cat_intend_gap domain_gap w_domain_gap
# 1  5.75              16.75             225.000000     1.380000   1.680000
# 2 65.00             -15.25               0.000000     2.700000   3.900000
# 3 25.00              11.25               0.000000     2.769231   3.288462
# 4  5.50               1.75              22.916667     4.125000   3.937500
# 5 18.75               3.00               8.333333     2.795455   2.914773
# 6  0.00              22.50               4.166667     2.857143   3.196429
#   overall_value_gap ⋯ ccs_virtue ccs_tradition ccs_selfC ccs_responsibility
# 1 20                ⋯ 28         34            31        33
# 2 60                ⋯ 38         17            19        38
# 3 35                ⋯ 25         32            43        38
# 4 50                ⋯ 36         37            41        40
# 5 35                ⋯ 40         34            41        43
# 6 30                ⋯ 35         32            41        34
#   ccs_industriousness needForCognition_score eisen_urg_imp eisen_Xurg_imp
# 1 30                  53                     50            35
# 2 24                  49                     50            10
# 3 41                  58                     30            20
# 4 40                  42                     50            20
# 5 43                  65                     10            40
# 6 43                  35                     50             0
#   eisen_urg_Ximp eisen_Xurg_Ximp
# 1 10              5
# 2 10             30
# 3 30             20
# 4 10             20
# 5 20             30
# 6  0             50

# %%
cor(df_streamlit$w_domain_gap, df_streamlit$domain_gap)
# Out:
# [1] 0.8593159
