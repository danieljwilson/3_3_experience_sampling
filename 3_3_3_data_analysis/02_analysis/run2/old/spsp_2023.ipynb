# %%
import plotly.graph_objects as go

import pandas as pd

import psutil

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/718417069ead87650b90472464c7565dc8c2cb1c/sunburst-coffee-flavors-complete.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/718417069ead87650b90472464c7565dc8c2cb1c/coffee-flavors.csv')

fig = go.Figure()

fig.add_trace(go.Sunburst(
    ids=df1.ids,
    labels=df1.labels,
    parents=df1.parents,
    domain=dict(column=0)
))

fig.add_trace(go.Sunburst(
    ids=df2.ids,
    labels=df2.labels,
    parents=df2.parents,
    domain=dict(column=1),
    maxdepth=2
))

fig.update_layout(
    grid= dict(columns=2, rows=1),
    margin = dict(t=0, l=0, r=0, b=0)
)

fig.show()

# %%
df1
# Out:
#                         ids            labels         parents
# 0                    Aromas            Aromas             NaN
# 1                    Tastes            Tastes             NaN
# 2          Aromas-Enzymatic         Enzymatic          Aromas
# 3     Aromas-Sugar Browning    Sugar Browning          Aromas
# 4   Aromas-Dry Distillation  Dry Distillation          Aromas
# ..                      ...               ...             ...
# 91            Pungent-Thyme             Thyme   Spicy-Pungent
# 92             Smokey-Tarry             Tarry  Carbony-Smokey
# 93      Smokey-Pipe Tobacco      Pipe Tobacco  Carbony-Smokey
# 94               Ashy-Burnt             Burnt    Carbony-Ashy
# 95             Ashy-Charred           Charred    Carbony-Ashy
#
# [96 rows x 3 columns]

# %%
df3 = pd.read_csv('/Users/djw/Downloads/Sunburst Plot SPSP 2023 - Sheet1.csv')

# %%
df3
# Out:
#                    name       parent
# 0               Passive          NaN
# 1                Active          NaN
# 2            Continuous      Passive
# 3                 Daily       Active
# 4                Weekly       Active
# ..                  ...          ...
# 93        Walking Speed     Wearable
# 94     Time at Location  Smart Phone
# 95            REM Sleep     Wearable
# 96    Other Wearable...     Wearable
# 97  Other Smartphone...  Smart Phone
#
# [98 rows x 2 columns]

# %%
fig = go.Figure()

fig.add_trace(go.Sunburst(
    ids=df3.name,
    labels=df3.name,
    parents=df3.parent,
    textfont=dict(size=[50, 50, 
                        30, 30, 30, 30, 30,
                        25, 25, 25, 25, 25, 25, 25,
                       ])
))


fig.update_layout(
    height=2000,
    grid= dict(columns=1, rows=1),
    margin = dict(t=0, l=0, r=0, b=0)
)

# %%
fig.write_image('test.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d0f4ce4489b8> in <module>
# ----> 1 fig.write_image('test.png')
#
# ~/opt/miniconda3/envs/thesis_env/lib/python3.8/site-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3238         import plotly.io as pio
#    3239
# -> 3240         return pio.write_image(self, *args, **kwargs)
#    3241
#    3242     # Static helpers
#
# ~/opt/miniconda3/envs/thesis_env/lib/python3.8/site-packages/plotly/io/_orca.py in write_image(fig, file, format, scale, width, height, validate)
#    1767     # -------------
#    1768     # Do this first so we don't create a file if image conversion fails
# -> 1769     img_data = to_image(
#    1770         fig, format=format, scale=scale, width=width, height=height, validate=validate
#    1771     )
#
# ...

# %%
fig.write_image('test.pdf', wid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-339dd7277539> in <module>
# ----> 1 fig.write_image('test.pdf')
#
# ~/opt/miniconda3/envs/thesis_env/lib/python3.8/site-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3238         import plotly.io as pio
#    3239
# -> 3240         return pio.write_image(self, *args, **kwargs)
#    3241
#    3242     # Static helpers
#
# ~/opt/miniconda3/envs/thesis_env/lib/python3.8/site-packages/plotly/io/_orca.py in write_image(fig, file, format, scale, width, height, validate)
#    1767     # -------------
#    1768     # Do this first so we don't create a file if image conversion fails
# -> 1769     img_data = to_image(
#    1770         fig, format=format, scale=scale, width=width, height=height, validate=validate
#    1771     )
#
# ...

# %%
! conda install -c plotly plotly=5.13.0 -y
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: / ^C
# failed with initial frozen solve. Retrying with flexible solve.
#
# CondaError: KeyboardInterrupt

# %%
! conda update -n base -c defaults conda

# %%
import plotly.express as px

# %%
# df = px.data.gapminder().query("continent == 'Europe' and year == 2007 and pop > 2.e6")
fig = px.bar(df, y='value', x='measure', color='value', color_continuous_scale=px.colors.sequential.Greys_r,
             range_color= (-1,0),
             text='value',
            )
fig.update_traces(textfont_size=33, textangle=0, textposition="inside", cliponaxis=False)
fig.update_layout(
                                plot_bgcolor='rgba(0, 0, 0, 0)',
                                paper_bgcolor='rgba(0, 0, 0, 0)',
                            )


fig.show()

# %%
df = pd.read_csv('/Users/djw/Downloads/Sunburst Plot SPSP 2023 - Sheet2.csv')

# %%
df_subs = pd.read_csv('/Users/djw/Downloads/Subjects-Run 2 Subjects.csv')
df_jacob = pd.read_csv('/Users/djw/Documents/pCloud_synced/Academics/Projects/2020_thesis/thesis_experiments/3_experiments/3_3_experience_sampling/3_3_1_raw_data/run_2/run2_jacob_onB.csv')

# %%
df_jacob = df_jacob.iloc[2:] 
df_subs = df_subs.iloc[2:]

# %%
list(df_jacob.loc[df_jacob.Progress=='100'].subject.sort_values())
# Out:
# ['10009688866',
#  '1006058132',
#  '1006740270',
#  '1007022687',
#  '1007143707',
#  '1007220053',
#  '1007252250',
#  '1008083057',
#  '1008233109',
#  '1008305362',
#  '1008411657',
#  '1008491918',
#  '1008784512',
#  '1008799622',
#  '1008801209',
#  '1008823579',
#  '1008823579',
#  '1008882032',
#  '1008896964',
#  '1008912456',
#  '1008915952',
#  '1008968663',
#  '1008991003',
#  '1009008574',
#  '1009021933',
#  '1009028598',
#  '1009054844',
#  '1009067670',
#  '1009067670',
#  '1009075411',
#  '1009077428',
#  '1009098138',
#  '1009108653',
#  '1009122334',
#  '1009149011',
#  '1009149011',
#  '1009152293',
#  '1009156155',
#  '1009158091',
#  '1009158233',
#  '1009159198',
#  '1009161354',
#  '1009189520',
#  '1009251015',
#  '1009251952',
#  '1009256902',
#  '1009264136',
#  '1009264314',
#  '1009281199',
#  '1009290688',
#  '1009293854',
#  '1009296423',
#  '1009297397',
#  '1009298387',
#  '1009302247',
#  '1009303512',
#  '1009315812',
#  '1009322458',
# ...

# %%
df_subs['Student Number'] = df_subs['Student Number'].astype('str')

# %%
df = pd.merge(df_jacob, df_subs, how='left', left_on='subject', right_on='Student Number')

# %%
list(df.sort_values(by='Student Number')['Student Number'])
# Out:
# ['1006740270',
#  '1007022687',
#  '1007143707',
#  '1007220053',
#  '1007252250',
#  '1008083057',
#  '1008233109',
#  '1008305362',
#  '1008411657',
#  '1008491918',
#  '1008784512',
#  '1008799622',
#  '1008801209',
#  '1008882032',
#  '1008896964',
#  '1008912456',
#  '1008915952',
#  '1008991003',
#  '1009008574',
#  '1009021933',
#  '1009028598',
#  '1009054844',
#  '1009077428',
#  '1009098138',
#  '1009108653',
#  '1009122334',
#  '1009152293',
#  '1009156155',
#  '1009158091',
#  '1009158233',
#  '1009159198',
#  '1009161354',
#  '1009189520',
#  '1009251952',
#  '1009264136',
#  '1009264314',
#  '1009281199',
#  '1009290688',
#  '1009293854',
#  '1009296423',
#  '1009297397',
#  '1009302247',
#  '1009303512',
#  '1009315812',
#  '1009322458',
#  '1009329745',
#  '1009364643',
#  '1009368435',
#  '1009387539',
#  '1009399964',
#  '1009400042',
#  '1009400284',
#  '1009409052',
#  '1009410219',
#  '1009498820',
#  '1009508310',
#  '1009509621',
#  '1009578672',
# ...

# %%
df_jacob.
